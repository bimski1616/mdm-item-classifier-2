# %%
import pandas as pd
import re

# %%
df = pd.read_csv("Output.csv")
df.head()
# Out:
#                                     item_description
# 0            CS spare part handling helpdesk Service
# 1  TSEL_GUL_NPX_New Enhanced Network Operating Mo...
# 2  TSEL_GUL_NPX_New Enhanced Network Operating Mo...
# 3  TSEL_GUL_NPX_New Enhanced Network Operating Mo...
# 4     TSEL Lumpsum Site Keeper and Comm-case Fix Fee

# %%
HIERARCHY = {
    1: "Managed Services",
    2: "Helpdesk & Support Services",
    3: "Services Package",
    4: "Network & Site Assurance",
    5: "Site Operation Services",
    6: "Infrastructure & Power Support",
    7: "Onsite Technical Support Services"
}

# %%
RULES = [
    (["helpdesk", "spare part"], 3),
    (["vip", "complaint", "assurance"], 4),
    (["site keeper", "maintenance"], 5),
    (["pln", "kva", "power"], 6),
    (["installation", "commissioning", "onsite"], 7),
]

# %%
def classify_item(desc):
    desc = str(desc).lower()
    stop_level = 3

    for keywords, level in RULES:
        if any(k in desc for k in keywords):
            stop_level = max(stop_level, level)

    return {f"L{i}": HIERARCHY[i] if i <= stop_level else "" for i in range(1, 8)}

# %%
result = df["item_description"].apply(classify_item)
df_out = pd.concat([df, result.apply(pd.Series)], axis=1)
df_out.head(10)
# Out:
#                                     item_description                L1  \
# 0            CS spare part handling helpdesk Service  Managed Services
# 1  TSEL_GUL_NPX_New Enhanced Network Operating Mo...  Managed Services
# 2  TSEL_GUL_NPX_New Enhanced Network Operating Mo...  Managed Services
# 3  TSEL_GUL_NPX_New Enhanced Network Operating Mo...  Managed Services
# 4     TSEL Lumpsum Site Keeper and Comm-case Fix Fee  Managed Services
# 5                 Upgrade PLN Connection for per kVA  Managed Services
# 6  IRO_FBB Common,Survey,Site Survey with site vi...  Managed Services
# 7  IRO_Datacomm,Box/Small,New Build, 1 PCS Box/Sm...  Managed Services
# 8  IRO_Datacomm,Commissioning & Integration, Supp...  Managed Services
# 9  IRO_Datacomm,Peering Link Expansion onsite Sup...  Managed Services
#
#                             L2                L3                        L4  \
# 0  Helpdesk & Support Services  Services Package
# 1  Helpdesk & Support Services  Services Package  Network & Site Assurance
# 2  Helpdesk & Support Services  Services Package  Network & Site Assurance
# 3  Helpdesk & Support Services  Services Package  Network & Site Assurance
# 4  Helpdesk & Support Services  Services Package  Network & Site Assurance
# 5  Helpdesk & Support Services  Services Package  Network & Site Assurance
# 6  Helpdesk & Support Services  Services Package
# 7  Helpdesk & Support Services  Services Package  Network & Site Assurance
# 8  Helpdesk & Support Services  Services Package  Network & Site Assurance
# 9  Helpdesk & Support Services  Services Package  Network & Site Assurance
#
#                         L5                              L6  \
# 0
# 1
# 2
# 3
# 4  Site Operation Services
# 5  Site Operation Services  Infrastructure & Power Support
# 6
# 7  Site Operation Services  Infrastructure & Power Support
# 8  Site Operation Services  Infrastructure & Power Support
# 9  Site Operation Services  Infrastructure & Power Support
#
#                                   L7
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7  Onsite Technical Support Services
# 8  Onsite Technical Support Services
# 9  Onsite Technical Support Services

# %%
df_out.isna().sum()
df_out[df_out["L7"] == ""].head()
# Out:
#                                     item_description                L1  \
# 0            CS spare part handling helpdesk Service  Managed Services
# 1  TSEL_GUL_NPX_New Enhanced Network Operating Mo...  Managed Services
# 2  TSEL_GUL_NPX_New Enhanced Network Operating Mo...  Managed Services
# 3  TSEL_GUL_NPX_New Enhanced Network Operating Mo...  Managed Services
# 4     TSEL Lumpsum Site Keeper and Comm-case Fix Fee  Managed Services
#
#                             L2                L3                        L4  \
# 0  Helpdesk & Support Services  Services Package
# 1  Helpdesk & Support Services  Services Package  Network & Site Assurance
# 2  Helpdesk & Support Services  Services Package  Network & Site Assurance
# 3  Helpdesk & Support Services  Services Package  Network & Site Assurance
# 4  Helpdesk & Support Services  Services Package  Network & Site Assurance
#
#                         L5 L6 L7
# 0
# 1
# 2
# 3
# 4  Site Operation Services

# %%
df_out.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 887 entries, 0 to 886
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   item_description  887 non-null    object
#  1   L1                887 non-null    object
#  2   L2                887 non-null    object
#  3   L3                887 non-null    object
#  4   L4                887 non-null    object
#  5   L5                887 non-null    object
#  6   L6                887 non-null    object
#  7   L7                887 non-null    object
# dtypes: object(8)
# memory usage: 55.6+ KB

# %%
df_out.head()
# Out:
#                                     item_description                L1  \
# 0            CS spare part handling helpdesk Service  Managed Services
# 1  TSEL_GUL_NPX_New Enhanced Network Operating Mo...  Managed Services
# 2  TSEL_GUL_NPX_New Enhanced Network Operating Mo...  Managed Services
# 3  TSEL_GUL_NPX_New Enhanced Network Operating Mo...  Managed Services
# 4     TSEL Lumpsum Site Keeper and Comm-case Fix Fee  Managed Services
#
#                             L2                L3                        L4  \
# 0  Helpdesk & Support Services  Services Package
# 1  Helpdesk & Support Services  Services Package  Network & Site Assurance
# 2  Helpdesk & Support Services  Services Package  Network & Site Assurance
# 3  Helpdesk & Support Services  Services Package  Network & Site Assurance
# 4  Helpdesk & Support Services  Services Package  Network & Site Assurance
#
#                         L5 L6 L7
# 0
# 1
# 2
# 3
# 4  Site Operation Services
